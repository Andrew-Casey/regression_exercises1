# %%
#doing things with data
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns
import env
import wrangle as w

# %%
#outliers eliminated at >3 stddev
df = w.wrangle_zillow3()
df
# Out:
# csv file found and loaded
#          taxvalue  rooms  bath    sqft   built       tax    fips
# 4        296425.0    4.0   2.0  3633.0  2005.0   6941.39  6037.0
# 6        847770.0    3.0   4.0  1620.0  2011.0  10244.94  6037.0
# 7        646760.0    3.0   2.0  2077.0  1926.0   7924.68  6037.0
# 18       169471.0    3.0   1.0  1244.0  1950.0   2532.88  6037.0
# 19       233266.0    3.0   2.0  1300.0  1950.0   3110.99  6037.0
# ...           ...    ...   ...     ...     ...       ...     ...
# 2152856  422400.0    4.0   4.0  4375.0  2015.0  13877.56  6037.0
# 2152858  960756.0    4.0   3.0  2262.0  2015.0  13494.52  6059.0
# 2152859  536061.0    4.0   4.5  3127.0  2014.0   6244.16  6059.0
# 2152861  424353.0    3.0   2.5  1974.0  2015.0   5302.70  6059.0
# 2152862  554009.0    4.0   4.0  2110.0  2014.0   6761.20  6037.0
#
# [2086487 rows x 7 columns]

# %%
df.shape
# Out:
# (2086487, 7)

# %% [markdown]
# # Visualize taxvalue

# %%
sns.histplot(df.taxvalue)
plt.show()

# %% [markdown]
# # Visualize rooms

# %%
sns.countplot(x=df.rooms)
plt.show()

# %% [markdown]
# # Visualize bath rooms

# %%
sns.countplot(x=df.bath)
plt.show()

# %% [markdown]
# # Visualize square footage

# %%
sns.histplot(x=df.sqft)
plt.show()

# %% [markdown]
# # Visualize year built

# %%
sns.histplot(x=df.built)
plt.show()

# %% [markdown]
# # Visualize taxes

# %%
sns.histplot(x=df.tax)
plt.show()

# %% [markdown]
# # Visualize FIPS

# %%
sns.countplot(x=df.fips)
plt.show()

# %% [markdown]
# # Visualize pairplot

# %%
sns.pairplot(data=df, corner=True)
plt.show()

# %% [markdown]
# # split into train, validate and test

# %%
train, validate, test = w.split_data(df)
train
# Out:
#           taxvalue  rooms  bath    sqft   built       tax    fips
# 1712623   452670.0    3.0   2.0  1446.0  1974.0   5308.48  6111.0
# 1549940   320536.0    3.0   3.0  1425.0  1987.0   4229.04  6059.0
# 2040410    99028.0    6.0   2.0  2338.0  1952.0   4557.37  6037.0
# 2094418  1155386.0    4.0   4.0  2624.0  1963.0  13064.89  6037.0
# 2019979    74518.0    1.0   1.0   540.0  1936.0   1119.83  6037.0
# ...            ...    ...   ...     ...     ...       ...     ...
# 731641    518000.0    3.0   2.0  1363.0  1967.0   6421.07  6037.0
# 5685      439000.0    2.0   1.0   908.0  1942.0   5242.35  6037.0
# 1459661   445693.0    3.0   2.0  1248.0  1920.0   5361.61  6037.0
# 1213074   355337.0    3.0   1.0  1367.0  1953.0   4449.37  6037.0
# 35782      21422.0    2.0   1.0   528.0  1921.0    389.68  6037.0
#
# [1251891 rows x 7 columns]
