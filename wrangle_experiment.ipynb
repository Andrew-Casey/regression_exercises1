# %%
#doing things with data
import pandas as pd
import numpy as np


import matplotlib.pyplot as plt
import seaborn as sns
import env
import wrangle as w

# %%
# outliers eliminated at > 4 stddev
df = w.wrangle_zillow2()
df
# Out:
# csv file found and loaded
#          taxvalue  rooms  bath    sqft   built       tax    fips
# 4        296425.0    4.0   2.0  3633.0  2005.0   6941.39  6037.0
# 6        847770.0    3.0   4.0  1620.0  2011.0  10244.94  6037.0
# 7        646760.0    3.0   2.0  2077.0  1926.0   7924.68  6037.0
# 11         5328.0    0.0   0.0  1200.0  1972.0     91.60  6037.0
# 14         6920.0    0.0   0.0   171.0  1973.0    255.17  6037.0
# ...           ...    ...   ...     ...     ...       ...     ...
# 2152856  422400.0    4.0   4.0  4375.0  2015.0  13877.56  6037.0
# 2152858  960756.0    4.0   3.0  2262.0  2015.0  13494.52  6059.0
# 2152859  536061.0    4.0   4.5  3127.0  2014.0   6244.16  6059.0
# 2152861  424353.0    3.0   2.5  1974.0  2015.0   5302.70  6059.0
# 2152862  554009.0    4.0   4.0  2110.0  2014.0   6761.20  6037.0
#
# [2117066 rows x 7 columns]

# %%
df.shape
# Out:
# (2117066, 7)

# %% [markdown]
# # Visualize taxvalue

# %%
sns.histplot(df.taxvalue)
plt.show()

# %% [markdown]
# # Visualize rooms

# %%
sns.countplot(x=df.rooms)
plt.show()

# %% [markdown]
# # Visualize bath rooms

# %%
sns.countplot(x=df.bath)
plt.show()

# %% [markdown]
# # Visualize square footage

# %%
sns.histplot(x=df.sqft)
plt.show()

# %% [markdown]
# # Visualize year built

# %%
sns.histplot(x=df.built)
plt.show()

# %% [markdown]
# # Visualize taxes

# %%
sns.histplot(x=df.tax)
plt.show()

# %% [markdown]
# # Visualize FIPS

# %%
sns.countplot(x=df.fips)
plt.show()

# %% [markdown]
# # Visualize pairplot

# %%
sns.pairplot(data=df, corner=True)
plt.show()

# %% [markdown]
# # split into train, validate, and test

# %%
train, validate, test = w.split_data(df)
train
# Out:
#           taxvalue  rooms  bath    sqft   built       tax    fips
# 1374724    67179.0    4.0   2.0  1299.0  1953.0   1157.00  6037.0
# 710603    392000.0    4.0   4.0  3245.0  2006.0   4961.30  6037.0
# 1601701   426495.0    4.0   2.0  1310.0  1956.0   5025.66  6059.0
# 789232    882791.0    3.0   3.0  2515.0  1936.0  10792.16  6037.0
# 1602034   562791.0    4.0   2.5  1791.0  1995.0   6421.20  6059.0
# ...            ...    ...   ...     ...     ...       ...     ...
# 349487    283501.0    2.0   1.0  1042.0  1937.0   3965.78  6037.0
# 96918    1134376.0    4.0   4.5  2992.0  2014.0  11766.46  6059.0
# 442770     90246.0    3.0   2.0  1510.0  1937.0   1231.47  6037.0
# 1952999   707569.0    3.0   3.0  1962.0  1956.0   9000.37  6037.0
# 1613666   226479.0    3.0   2.0  1344.0  1969.0   2611.80  6059.0
#
# [1270239 rows x 7 columns]
